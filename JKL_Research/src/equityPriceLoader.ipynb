# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import matplotlib
import matplotlib.pyplot as plt

# Read S&P 500 Stock Tickers
tickerFile = '../data/list_SP500_test.csv'
sp500_list = pd.read_csv(tickerFile)
print (sp500_list['Ticker'])
goog = web.DataReader(sp500_list['Ticker'], data_source='yahoo', start='1/1/2016')

daily_ret = np.log(goog['Close']/goog['Close'].shift(1))
daily_ret.rolling(window=252,center=False).std()*np.sqrt(252)
# goog['Log_Ret'] = np.log(goog['Close'] / goog['Close'].shift(1))
# goog['Volatility'] = goog['Log_Ret'].rolling(window=252,center=False).std()*np.sqrt(252)
# print ('Processed \n',sp500_list['Ticker'])
# Out:
# 0     GOOG
# 1    ^GSPC
# Name: Ticker, dtype: object
# Symbols         GOOG     ^GSPC
# Date
# 2016-01-04       NaN       NaN
# 2016-01-05       NaN       NaN
# 2016-01-06       NaN       NaN
# 2016-01-07       NaN       NaN
# 2016-01-08       NaN       NaN
# 2016-01-11       NaN       NaN
# 2016-01-12       NaN       NaN
# 2016-01-13       NaN       NaN
# 2016-01-14       NaN       NaN
# 2016-01-15       NaN       NaN
# 2016-01-19       NaN       NaN
# 2016-01-20       NaN       NaN
# 2016-01-21       NaN       NaN
# 2016-01-22       NaN       NaN
# 2016-01-25       NaN       NaN
# 2016-01-26       NaN       NaN
# 2016-01-27       NaN       NaN
# 2016-01-28       NaN       NaN
# 2016-01-29       NaN       NaN
# 2016-02-01       NaN       NaN
# 2016-02-02       NaN       NaN
# 2016-02-03       NaN       NaN
# 2016-02-04       NaN       NaN
# 2016-02-05       NaN       NaN
# 2016-02-08       NaN       NaN
# 2016-02-09       NaN       NaN
# 2016-02-10       NaN       NaN
# 2016-02-11       NaN       NaN
# 2016-02-12       NaN       NaN
# 2016-02-16       NaN       NaN
# ...              ...       ...
# 2018-08-16  0.227253  0.125891
# 2018-08-17  0.226570  0.124876
# 2018-08-20  0.226611  0.124864
# 2018-08-21  0.226629  0.124871
# 2018-08-22  0.225891  0.124530
# 2018-08-23  0.225902  0.124485
# 2018-08-24  0.226079  0.124579
# 2018-08-27  0.226540  0.124771
# 2018-08-28  0.226727  0.124771
# 2018-08-29  0.227019  0.124872
# 2018-08-30  0.227079  0.124915
# 2018-08-31  0.227611  0.124813
# 2018-09-04  0.228347  0.124827
# 2018-09-05  0.228316  0.124603
# 2018-09-06  0.228723  0.124652
# 2018-09-07  0.228682  0.124682
# 2018-09-10  0.228417  0.124671
# 2018-09-11  0.228626  0.124292
# 2018-09-12  0.229005  0.124262
# 2018-09-13  0.229204  0.124350
# 2018-09-14  0.228930  0.124339
# 2018-09-17  0.229345  0.124486
# 2018-09-18  0.229275  0.124575
# 2018-09-19  0.229307  0.124576
# 2018-09-20  0.229444  0.124785
# 2018-09-21  0.230198  0.124734
# 2018-09-24  0.230203  0.124803
# 2018-09-25  0.230182  0.124786
# 2018-09-26  0.230203  0.124846
# 2018-09-27  0.229588  0.124816
#
# [690 rows x 2 columns]
